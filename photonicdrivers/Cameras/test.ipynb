# %%
from photonicdrivers.SNSPDs.SNSPD_02_SQ_Driver import SNSPD_02_SQ_Driver

# %%
snspd = SNSPD_02_SQ_Driver("10.209.70.234")

# %%
snspd.connect()
# Out:
# Successfully connected to WebSQController at http://10.209.70.234
