# %%
from photonicdrivers.Microwave_Source.Valon5019_Driver import Valon5019_Driver
valon = Valon5019_Driver(port="COM3")

valon.connect()
print(valon.is_connected())
valon.disconnect()
print(valon.is_connected())
# Out:
# Serial port COM3 opened successfully.
# True
# False

# %% [markdown]
# Test "is_connected"

# %%
valon.connect()
print(valon.is_connected())
valon.disconnect()
print(valon.is_connected())
# Out:
# Error opening serial port: could not open port 'COM3': PermissionError(13, 'Access is denied.', None, 5)
# True
# False

# %%
valon.connect()
print(valon.is_connected())
# Out:
# Serial port COM3 opened successfully.
# True

# %%
valon.send_command("FREQ?")
valon._query("FREQ?")
# Out:
# Response from device: FREQ?
# F 100 MHz; // Act 100 MHz
# -->
# 'FREQ?\r\nF 100 MHz; // Act 100 MHz\r\n\r-->'

# %%
valon._query("FREQ?")
# Out:
# 'FREQ?\r\nF 100 MHz; // Act 100 MHz\r\n\r-->'

# %%
valon._query("PWR -40")
print(valon._query("PWR?"))

#valon._query("PLevel 32")
valon._query("ATT?")
# Out:
# PWR?
# PWR -40.00; // dBm
# -->
# 'ATT?\r\nATT 56.00; // dB\r\n\r-->'

# %%
valon._query("FREQ 2500")
valon._query("FREQ?")
# Out:
# 'FREQ?\r\nF 2500 MHz; // Act 2500 MHz\r\n\r-->'

# %%
valon.get_power_dBm()
# Out:
# 15.0

# %%
valon._query("FREQ?")
# Out:
# 'FREQ?\r\nF 2500 MHz; // Act 2500 MHz\r\n\r-->'

# %%
valon.get_frequency_MHz()
# Out:
# 2500.0

# %%
valon._query("MODe?")
# Out:
# 'MODe?\r\nMODE CW;\r\n\r-->'

# %%
valon._query("START?")
# Out:
# 'START?\r\nSTART 23 MHz; // Act 23 MHz\r\n\r-->'

# %%
valon._query("STOP?")
# Out:
# 'STOP?\r\nSTOP 6000 MHz; // Act 6000 MHz\r\n\r-->'

# %%
valon._query("FSTEP?")
# Out:
# 'FSTEP?\r\nFSTEP 10 MHz;\r\n\r-->'

# %%
valon._query("STEP?")
# Out:
# 'STEP?\r\nSTEP 1 MHz;\r\n\r-->'

# %%
valon._query("RATE?")
# Out:
# 'RATE?\r\nRATE 1000; // ms\r\n\r-->'

# %%
valon._query("RTIME?")
# Out:
# 'RTIME?\r\nRTIME 0; // ms\r\n\r-->'

# %%
valon._query("SWEEPLIST?")
# Out:
# 'SWEEPLIST?\r\nSwp(0) = 23 MHz; // Act 23 MHz\r\nSwp(1) = 24 MHz; // Act 24 MHz\r\nSwp(2) = 25 MHz; // Act 25 MHz\r\nSwp(3) = 26 MHz; // Act 26 MHz\r\nSwp(4) = 27 MHz; // Act 27 MHz\r\nSwp(5) = 28 MHz; // Act 28 MHz\r\nSwp(6) = 29 MHz; // Act 29 MHz\r\nSwp(7) = 30 MHz; // Act 30 MHz\r\nSwp(8) = 31 MHz; // Act 31 MHz\r\nSwp(9) = 32 MHz; // Act 32 MHz\r\nSwp(10) = 33 MHz; // Act 33 MHz\r\nSwp(11) = 34 MHz; // Act 34 MHz\r\nSwp(12) = 35 MHz; // Act 35 MHz\r\nSwp(13) = 36 MHz; // Act 36 MHz\r\nSwp(14) = 37 MHz; // Act 37 MHz\r\nSwp(15) = 38 MHz; // Act 38 MHz\r\nSwp(16) = 39 MHz; // Act 39 MHz\r\nSwp(17) = 40 MHz; // Act 40 MHz\r\nSwp(18) = 41 MHz; // Act 41 MHz\r\nSwp(19) = 42 MHz; // Act 42 MHz\r\n\r-->'

# %%
valon._query("PDN?")
# Out:
# 'PDN?\r\nPDN 1;\r\n\r-->'

# %%
valon._query("LOCK?")
# Out:
# 'PDN 1;\r\n\r-->LOCK?\r\nSUB1       :     locked\r\nSUB2       :     locked\r\nMAIN SYNTH :     locked\r\n\r-->'

# %%
valon.get_mode()
# Out:
# 'CW'

# %%
valon.set_lock(True)

# %%
valon.is_locked()
# Out:
# False

# %%
valon._query("PDN?")
# Out:
# 'PDN?\r\nPDN 0;\r\n\r-->'

# %%
valon._query("TMODe?")
# Out:
# 'TMODe?\r\nTMODe AUTO;\r\n\r-->'
