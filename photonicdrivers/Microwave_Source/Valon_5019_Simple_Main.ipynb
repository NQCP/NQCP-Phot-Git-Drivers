# %%
from photonicdrivers.Microwave_Source.Valon_5019_Driver import Valon_5019_Driver

valon = Valon_5019_Driver(port="COM3")
valon.connect()
print(valon.is_connected())
# valon.disconnect()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[2], line 4
#       1 from photonicdrivers.Microwave_Source.Valon_5019_Driver import Valon_5019_Driver
#       3 valon = Valon_5019_Driver(port="COM3")
# ----> 4 valon.connect()
#       5 print(valon.is_connected())
#       6 # valon.disconnect()
#
# File C:\gitRepositories\NQCP-Phot-Git-Drivers\photonicdrivers\Microwave_Source\Valon_5019_Driver.py:96, in connect(self, port_name, baud_rate, timeout)
#      93 print(f"Serial port {port_name} opened successfully.")
#      95 if self.is_connected():
# ---> 96     self.set_baud_rate(baud_rate)
#      97 self.connection.close()
#      99 self.connection = serial.Serial(port_name, baud_rate, timeout=timeout)
#
# File c:\Users\NQCPQP\miniconda3\envs\python312\Lib\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File c:\Users\NQCPQP\miniconda3\envs\python312\Lib\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File c:\Users\NQCPQP\miniconda3\envs\python312\Lib\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM3': PermissionError(13, 'Access is denied.', None, 5)

# %% [markdown]
# Test "is_connected"

# %%
print(valon.baud_rate)
# Out:
# 9600

# %%
valon.set_frequency_MHz(2000)
valon.set_power_dBm(15)

# %%
valon.send_command("ID?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 valon.send_command("ID?")
#
# File C:\gitRepositories\NQCP-Phot-Git-Drivers\photonicdrivers\Microwave_Source\Valon_5019_Driver.py:140, in Valon_5019_Driver.send_command(self, command, delay)
#     137     delay = self.delay
#     138 try:
#     139     # Clear the input buffer
# --> 140     self.connection.reset_input_buffer()
#     142     # Send the command with a carriage return
#     143     command_with_cr = f"{command}\r"
#
# AttributeError: 'NoneType' object has no attribute 'reset_input_buffer'

# %%
valon._query("FREQ?", delay=4)
# Out:
# '\x00'

# %%
valon._query("ID?")
# Out:
# 'ID?\r\nValon Technology, 5019, 12204685, R7  version 2.0l   Build: Sep 15 2025  02:51:54\r\nchangeset git hash: d359c344  2025-09-15 02:50:45 -0700\r\n\r-->'

# %%
valon.get_sweep_stop_frequency_MHz()
# Out:
# 6000.0

# %%
valon._query("PWR -40")
print(valon._query("PWR?"))

# valon._query("PLevel 32")
valon._query("ATT?")
# Out:
# PWR?
# PWR -40.00; // dBm
# -->
# 'ATT?\r\nATT 56.00; // dB\r\n\r-->'

# %%
valon._query("FREQ 2500")
valon._query("FREQ?")
# Out:
# '\x00'

# %%
valon.get_power_dBm()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 valon.get_power_dBm()
#
# File C:\gitRepositories\NQCP-Phot-Git-Drivers\photonicdrivers\Microwave_Source\Valon_5019_Driver.py:171, in Valon_5019_Driver.get_power_dBm(self)
#     168             except ValueError:
#     169                 pass
# --> 171 raise RuntimeError(f"No valid PWR response found: {response}")
#
# RuntimeError: No valid PWR response found:

# %%
valon._query("FREQ?")
# Out:
# '\x00'

# %%
valon.get_frequency_MHz()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 valon.get_frequency_MHz()
#
# File C:\gitRepositories\NQCP-Phot-Git-Drivers\photonicdrivers\Microwave_Source\Valon_5019_Driver.py:186, in Valon_5019_Driver.get_frequency_MHz(self)
#     183             except ValueError:
#     184                 pass
# --> 186 raise RuntimeError(f"No valid frequency response found: {response}")
#
# RuntimeError: No valid frequency response found:

# %%
valon._query("MODe?")
# Out:
# '\x00\x00'

# %%
valon._query("START?")
# Out:
# '\x00'

# %%
valon._query("STOP?")
# Out:
# '\x00\x00\x00'

# %%
valon._query("FSTEP?")
# Out:
# '\x00\x00'

# %%
valon._query("STEP?")
# Out:
# '\x00\x00'

# %%
valon._query("RATE?")
# Out:
# '\x00'

# %%
valon._query("RTIME?")
# Out:
# 'RTIME?\r\nRTIME 0; // ms\r\n\r-->'

# %%
valon._query("SWEEPLIST?")
# Out:
# 'SWEEPLIST?\r\nSwp(0) = 23 MHz; // Act 23 MHz\r\nSwp(1) = 24 MHz; // Act 24 MHz\r\nSwp(2) = 25 MHz; // Act 25 MHz\r\nSwp(3) = 26 MHz; // Act 26 MHz\r\nSwp(4) = 27 MHz; // Act 27 MHz\r\nSwp(5) = 28 MHz; // Act 28 MHz\r\nSwp(6) = 29 MHz; // Act 29 MHz\r\nSwp(7) = 30 MHz; // Act 30 MHz\r\nSwp(8) = 31 MHz; // Act 31 MHz\r\nSwp(9) = 32 MHz; // Act 32 MHz\r\nSwp(10) = 33 MHz; // Act 33 MHz\r\nSwp(11) = 34 MHz; // Act 34 MHz\r\nSwp(12) = 35 MHz; // Act 35 MHz\r\nSwp(13) = 36 MHz; // Act 36 MHz\r\nSwp(14) = 37 MHz; // Act 37 MHz\r\nSwp(15) = 38 MHz; // Act 38 MHz\r\nSwp(16) = 39 MHz; // Act 39 MHz\r\nSwp(17) = 40 MHz; // Act 40 MHz\r\nSwp(18) = 41 MHz; // Act 41 MHz\r\nSwp(19) = 42 MHz; // Act 42 MHz\r\n\r-->'

# %%
valon._query("PDN?")
# Out:
# 'PDN?\r\nPDN 1;\r\n\r-->'

# %%
valon._query("LOCK?")
# Out:
# 'PDN 1;\r\n\r-->LOCK?\r\nSUB1       :     locked\r\nSUB2       :     locked\r\nMAIN SYNTH :     locked\r\n\r-->'

# %%
valon.get_mode()
# Out:
# 'CW'

# %%
valon.set_lock(True)

# %%
valon.is_locked()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 valon.is_locked()
#
# File C:\gitRepositories\NQCP-Phot-Git-Drivers\photonicdrivers\Microwave_Source\Valon_5019_Driver.py:141, in Valon_5019_Driver.is_locked(self)
#     138         if len(parts) >= 2:
#     139             return parts[1] == "1"
# --> 141 raise RuntimeError(f"No valid LOCK response found: {response}")
#
# RuntimeError: No valid LOCK response found:

# %%
valon._query("PDN?")
# Out:
# 'PDN?\r\nPDN 0;\r\n\r-->'

# %%
valon._query("TMODe?")
# Out:
# 'TMODe?\r\nTMODe AUTO;\r\n\r-->'
